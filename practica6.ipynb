# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def z(n, c):
    if n == 0:
        return 0
    else:
        return z(n - 1, c) ** 2 + c

# %%
def sequence(c):
    z = 0
    while True:
        yield z
        z = z ** 2 + c

for n, z in enumerate(sequence(c=1)):
    print(f"z({n}) = {z}")
    if n >= 20:
        break
# Out:
# z(0) = 0
# z(1) = 1
# z(2) = 2
# z(3) = 5
# z(4) = 26
# z(5) = 677
# z(6) = 458330
# z(7) = 210066388901
# z(8) = 44127887745906175987802
# z(9) = 1947270476915296449559703445493848930452791205
# z(10) = 3791862310265926082868235028027893277370233152247388584761734150717768254410341175325352026
# z(11) = 14378219780015246281818710879551167697596193767663736497089725524386087657390556152293078723153293423353330879856663164406809615688082297859526620035327291442156498380795040822304677
# z(12) = 
# z(13) = ...
# z(14) = ...
# z(15) = ...
# z(16) = ...
# z(17) = ...
# z(18) = ...
# z(19) = ...
# z(20) = ...

# %%
def complex_matrix(xmin, xmax, ymin, ymax, pixel_density):
    re = np.linspace(xmin, xmax, int((xmax - xmin) * pixel_density))
    im = np.linspace(ymin, ymax, int((ymax - ymin) * pixel_density))
    return re[np.newaxis, :] + im[:, np.newaxis] * 1j


def is_stable(c, num_iterations):
    z = 0
    for _ in range(num_iterations):
        z = z ** 2 + c
    return abs(z) <= 2


c = complex_matrix(-2, 0.5, -1.5, 1.5, pixel_density=512)
plt.imshow(is_stable(c, num_iterations=20), cmap="binary")
plt.gca().set_aspect("equal")
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_10648\3528543236.py:10: RuntimeWarning: overflow encountered in square
#   z = z ** 2 + c
# C:\Users\Alan\AppData\Local\Temp\ipykernel_10648\3528543236.py:10: RuntimeWarning: invalid value encountered in square
#   z = z ** 2 + c
# C:\Users\Alan\AppData\Local\Temp\ipykernel_10648\3528543236.py:11: RuntimeWarning: overflow encountered in absolute
#   return abs(z) <= 2
